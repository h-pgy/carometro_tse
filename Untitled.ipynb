# %%
from core.integrations.ckan import ckan

# %%
ckan.lst_pkgs()
# Out:
# Get request to url: https://dadosabertos.tse.jus.br/api/action/package_list
# ['candidatos-1933',
#  'candidatos-1934',
#  'candidatos-1945',
#  'candidatos-1947',
#  'candidatos-1950',
#  'candidatos-1954',
#  'candidatos-1955',
#  'candidatos-1958',
#  'candidatos-1960',
#  'candidatos-1962',
#  'candidatos-1965',
#  'candidatos-1966',
#  'candidatos-1970',
#  'candidatos-1974',
#  'candidatos-1978',
#  'candidatos-1982',
#  'candidatos-1986',
#  'candidatos-1989',
#  'candidatos-1990',
#  'candidatos-1994',
#  'candidatos-1996',
#  'candidatos-1998',
#  'candidatos-2000',
#  'candidatos-2002',
#  'candidatos-2004',
#  'candidatos-2006',
#  'candidatos-2008',
#  'candidatos-2010',
#  'candidatos-2012',
#  'candidatos-2014',
#  'candidatos-2016',
#  'candidatos-2018',
#  'candidatos-2020-subtemas',
#  'candidatos-2022',
#  'comparecimento-e-abstencao-2014',
#  'comparecimento-e-abstencao-2016',
#  'comparecimento-e-abstencao-2018',
#  'comparecimento-e-abstencao-2020',
# ...

# %%
ckan.lst_resources('resultados-2022-boletim-de-urna')
# Out:
# Get request to url: https://dadosabertos.tse.jus.br/api/action/package_show?id=resultados-2022-boletim-de-urna
# [{'cache_last_updated': None,
#   'cache_url': None,
#   'created': '2022-10-05T20:59:30.091415',
#   'datastore_active': False,
#   'description': '',
#   'format': 'CSV',
#   'hash': '',
#   'id': 'fdaba499-49eb-4bf7-be53-b34254efa38b',
#   'last_modified': None,
#   'metadata_modified': '2022-10-05T21:30:42.941300',
#   'mimetype': 'application/zip',
#   'mimetype_inner': None,
#   'name': 'AC - Boletim de Urna - Primeiro turno - 05.10.2022',
#   'package_id': 'd4f9edaa-c4a7-43b2-bca5-165b7e03c897',
#   'position': 0,
#   'resource_type': None,
#   'size': None,
#   'state': 'active',
#   'url': 'https://cdn.tse.jus.br/estatistica/sead/eleicoes/eleicoes2022/buweb/bweb_1t_AC_051020221321.zip',
#   'url_type': None},
#  {'cache_last_updated': None,
#   'cache_url': None,
#   'created': '2022-10-05T21:31:27.713223',
#   'datastore_active': False,
#   'description': '',
# ...
